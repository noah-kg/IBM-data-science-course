# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Noah Gampe**
#
# Aspiring Data Scientist

# %% [markdown]
# *I want to become a data scientist because I find data to be extremely fascinating. It's all around us, and there's not limit to what we can learn from it.*

# %% [markdown]
# ### The following cell (cell 5) will output the sum of a range of consecutive numbers 1 - N.

# %%
N = 100
answer = (N/2)*(1 + N)
print(f'The sum of consecutive numbers from 1 to {N} is {int(answer)}.')
# Out:
# The sum of consecutive numbers from 1 to 100 is 5050.

# %% [markdown]
# If you're interested in climbing/bouldering, follow me on [Instagram](https://www.instagram.com/noah_likes_climbing/).
# ---
# Some fun facts about me:
# * I have a Bachelor's Degree in Computer Engineering
# * I lived in South Korea for 6 years
# * I used to moonlight as a photographer
#
# One of my favorite quotes:
# > It is the mark of an edcuated mind to be able to entertain an idea without accepting it. -(Paraphrasing of) Aristotle
